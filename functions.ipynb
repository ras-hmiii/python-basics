# %%
#functions (reusable code )
#reusable code block,organize code ,readable

# %%
#Function Defination
def function_name(paramerters) :
    """Docstring explaining the function"""
    #function body
    #code to be executed
    return  #optional

# %%
def greet_user(name):
    """Function to greet a user by name"""
    print(f"Hello, {name}! Welcome to the Python world.")

# %%
#calling the function 
greet_user("Ganesh")
# Out:
# Hello, Ganesh! Welcome to the Python world.

# %%
#Parameters : variables listed in the function defination (placeholders)
#Arguments : values passed to the function (actual values)

temp1 = input ("Enter your name:")
greet_user(temp1)

# %%
def introduce(name,address,occupation):
    """This function introduces a person and their details."""
    print(f"My name is {name}.I live in {address}and i work as {occupation}")

# %%
#calling function with parameters multile using positional arguments
introduce("Sita","Kathmandu","Engineer")
introduce("man","doctor","hello")
# Out:
# My name is Sita.I live in Kathmanduand i work as Engineer
# My name is man.I live in doctorand i work as hello

# %%
#positional parameter requires the order of parameter and arguments bth to match

# %%
#Keyword Arguments 
def introduce_keyword(name,address,occupation):
    """This function introduces a person and their details."""
    print(f"My name is {name}.I live in {address}and i work as {occupation}")

# %%
introduce_keyword(occupation="Teacher",name="Sita",address="Nepal")
# Out:
# My name is Sita.I live in Nepaland i work as Teacher

# %%
#function defination with default parameter
def introduce_default(name,address,occupation="Unemployed"):
    """This is function introduces a persons with their details using default parameter"""
print(f"My name is {name}.I live in {address}and works in {occupation}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 def introduce_default(name,address,occupation="Unemployed"):
#       3     """This is function introduces a persons with their details using default parameter"""
# ----> 4 print(f"My name is {name}.I live in {address}and works in {occupation}")
#
# NameError: name 'name' is not defined

# %%
introduce_default("Laxmi","Dharan","Doctor")
introduce_default("Ram","heeloo")

# %%
#eg of args
def sum_all(*args):
    """This function returns sum of all arg"""
    total= sum(args)
    print(f"Sum: {total}")

# %%
sum_all(1,2,3,4)

# %%
def display_info(**kwargs):
    """This function display information passed as keyword arguments"""
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print("\n Displaying using **kwargs")
display_info(name="Ram",age="40")

# %%
#Returns statement sends values back to the caller

def calculate(a,b):
    """This fun returns the sum , diiference,products division of to numbers"""
    sum_result = a+b
    diff_value = a-b
    prod_value =a*b
    division_result =a/b
    return sum_result, diff_value, prod_value, division_result

# %%
fno = int(input("Enter number"))
sno = int(input("Enter 2nd number"))
sum_val,diff_val,prod_val,div_val = calculate(fno,sno)
print(f"Sum:{sum_val},Difference:{diff_val},product:{prod_val},Division:{div_val}")

# %%
def grading():
    marks = list(map(int, input("Enter marks of 5 subjects separated by space: ").split()))
    total = sum(marks)
    percentage = total / 5
    print(f"Total: {total}")
    print(f"Percentage: {percentage}%")

    if percentage >= 90:
        print("Excellent!")
    elif percentage >= 75:
        print("Good job!")
    elif percentage >= 50:
        print("You passed.")
    else:
        print("Try harder next time.")

grading()

# %%
#lambda function : small anonymous function
add_three = lambda a,b,c :( a+b+c)
add_three(5,10,15)
# Out:
# 30

# %%
#Map Function 
#The map() function applies a given function to all items in an input list (or any iterable) and returns an iterator.

nos = [5,10,15,20]
squared_nos = map(lambda x:x**2,nos)
print(squared_nos)
list(squared_nos)
# Out:
# ...
# [25, 100, 225, 400]

# %%
##fFilter Function
numbers = [1,2,2,3,4,4,5,6,7,8,9,10 ]
even_numbers = filter(lambda x: x % 2 == 0, numbers)
print(list(even_numbers))
# Out:
# [2, 2, 4, 4, 6, 8, 10]

# %%
def is_even(n):
  return n % 2 == 0

even_numbers1= filter(is_even, numbers)
print(list(even_numbers1))
# Out:
# [2, 2, 4, 4, 6, 8, 10]

# %%
print(numbers)
result = map(lambda x: x**2, filter(is_even, numbers))
print(list(result))
# Out:
# [1, 2, 2, 3, 4, 4, 5, 6, 7, 8, 9, 10]
# [4, 4, 16, 16, 36, 64, 100]

# %%
#Enumerate Function
#functions add a counter to an iterable and returns it as an enumerate object which yeidls pairs of index and element durin iteration 
#enumerate(iterable, start=0)

devices = ['laptop', 'tablet', 'smartphone'
           ]
for index, device in enumerate(devices, start=6):
    print(f"{index}: {device}")
# Out:
# 6: laptop
# 7: tablet
# 8: smartphone
